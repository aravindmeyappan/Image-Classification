# %%
import numpy as np
from skimage.io import imread, imshow

# %%
image = imread('mey.jpg')

# %%
imshow(image)

# %%
image
# Out:
# array([[[222, 202, 178],
#         [222, 202, 178],
#         [222, 202, 178],
#         ...,
#         [221, 199, 176],
#         [221, 199, 176],
#         [221, 199, 176]],
#
#        [[222, 202, 178],
#         [222, 202, 178],
#         [222, 202, 178],
#         ...,
#         [222, 200, 177],
#         [222, 200, 177],
#         [222, 200, 177]],
#
#        [[222, 202, 178],
#         [222, 202, 178],
#         [222, 202, 178],
#         ...,
#         [222, 200, 177],
#         [222, 200, 177],
#         [222, 200, 177]],
#
#        ...,
#
#        [[ 84, 137, 189],
#         [ 81, 134, 186],
#         [ 77, 128, 181],
#         ...,
#         [185, 219, 255],
#         [181, 215, 250],
#         [176, 210, 245]],
#
#        [[ 87, 140, 192],
#         [ 80, 133, 185],
#         [ 79, 130, 183],
#         ...,
#         [186, 220, 255],
#         [182, 216, 253],
#         [177, 211, 248]],
#
#        [[ 89, 142, 194],
#         [ 81, 134, 186],
#         [ 86, 137, 190],
# ...
